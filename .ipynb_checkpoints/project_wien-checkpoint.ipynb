# %% [markdown]
# # Fährt der Zug bei Regen noch? 🚉
#
# <img src="https://www.biorama.eu/wp-content/uploads/2016/02/Bildschirmfoto-2016-02-26-um-17.14.57.png"></img>
#
# ### Project Aim
# This Project aims to correlate, visualize and find patterns regarding the developments in the Viennese public transport grid and gauging public sentiment in correlation to such incidents.

# %% [markdown]
# ### Team Members
# Julian Deleja-Hotko\
# Nicolas Markl\
# Dionis Ramadani

# %% [markdown]
# ### Data Sources
# **// TODO: DIE VERSCHIEDENEN DATEN GENAUER BESCHREIBEN**
#
# ##### [Digitales Wien / Open Government Data Portal Wien](https://digitales.wien.gv.at/open-data/) - REST Endpoint
# Several hundred data sets provide detailed information about one-way streets, real-time information from Wiener Linien, historical aerial photographs, measurement data of air pollutants or WLAN locations, to name just a few areas.
#
# ##### [Öffi.at](öffi.at)  - XML / Web Scraping
# A website gathering and organizing historical data about Wiener Linien outages, courtesy of Klaus Kirnbauer.\
# Data available starting from July 2020.
#
# ##### [Twitter@WienerLinien](https://twitter.com/wienerlinien) - Web Scraping
# A social media platform popular in Vienna with dedicated accounts from public service providers, useful for gauging sentiment about specific routes in Vienna
#
# ##### [data.gv.at](data.gv.at) - Flat Files
# Gathering general info about the public transport network, usage, etc.

# %% [markdown]
# ### Architecture Diagram
# ![Architektur.drawio.png](attachment:Architektur.drawio.png)

# %% [markdown]
# ### Packages
# Here we'll install and import all relevant Python packages for this project

# %%
# !pip install pymongo
# !pip install pyspark
# !pip install requests
# !pip install beautifulsoup4
# !pip install pyspark 
# !pip install pandas
# !pip install geopandas
# !pip install meteostat
# !pip install geoplot
# Out:
# Requirement already satisfied: pymongo in /home/julian/anaconda3/lib/python3.9/site-packages (4.1.1)
# Requirement already satisfied: pyspark in /home/julian/anaconda3/lib/python3.9/site-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in /home/julian/anaconda3/lib/python3.9/site-packages (from pyspark) (0.10.9.3)
# Requirement already satisfied: requests in /home/julian/anaconda3/lib/python3.9/site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/julian/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/julian/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: beautifulsoup4 in /home/julian/anaconda3/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/julian/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: pyspark in /home/julian/anaconda3/lib/python3.9/site-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in /home/julian/anaconda3/lib/python3.9/site-packages (from pyspark) (0.10.9.3)
# Requirement already satisfied: pandas in /home/julian/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/julian/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/julian/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: geopandas in /home/julian/anaconda3/lib/python3.9/site-packages (0.11.0)
# Requirement already satisfied: pandas>=1.0.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: fiona>=1.8 in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: packaging in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely<2,>=1.7 in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.2)
# Requirement already satisfied: click>=4.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: certifi in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: cligj>=0.5 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=17 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: setuptools in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (61.2.0)
# Requirement already satisfied: six>=1.7 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: munch in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/julian/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/julian/anaconda3/lib/python3.9/site-packages (from packaging->geopandas) (3.0.4)
# Requirement already satisfied: meteostat in /home/julian/anaconda3/lib/python3.9/site-packages (1.6.2)
# Requirement already satisfied: pandas>=1.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from meteostat) (1.4.2)
# Requirement already satisfied: numpy in /home/julian/anaconda3/lib/python3.9/site-packages (from meteostat) (1.21.5)
# Requirement already satisfied: pytz in /home/julian/anaconda3/lib/python3.9/site-packages (from meteostat) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/julian/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.1->meteostat) (1.16.0)
# Requirement already satisfied: geoplot in /home/julian/anaconda3/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: mapclassify>=2.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from geoplot) (2.4.3)
# Requirement already satisfied: matplotlib>=3.1.2 in /home/julian/anaconda3/lib/python3.9/site-packages (from geoplot) (3.5.1)
# Requirement already satisfied: seaborn in /home/julian/anaconda3/lib/python3.9/site-packages (from geoplot) (0.11.2)
# Requirement already satisfied: contextily>=1.0.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from geoplot) (1.2.0)
# Requirement already satisfied: geopandas>=0.9.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from geoplot) (0.11.0)
# Requirement already satisfied: pandas in /home/julian/anaconda3/lib/python3.9/site-packages (from geoplot) (1.4.2)
# Requirement already satisfied: cartopy in /home/julian/anaconda3/lib/python3.9/site-packages (from geoplot) (0.20.1.dev132+g0af6163)
# Requirement already satisfied: pillow in /home/julian/anaconda3/lib/python3.9/site-packages (from contextily>=1.0.0->geoplot) (9.0.1)
# Requirement already satisfied: requests in /home/julian/anaconda3/lib/python3.9/site-packages (from contextily>=1.0.0->geoplot) (2.27.1)
# Requirement already satisfied: geopy in /home/julian/anaconda3/lib/python3.9/site-packages (from contextily>=1.0.0->geoplot) (2.2.0)
# Requirement already satisfied: rasterio in /home/julian/anaconda3/lib/python3.9/site-packages (from contextily>=1.0.0->geoplot) (1.2.10)
# Requirement already satisfied: mercantile in /home/julian/anaconda3/lib/python3.9/site-packages (from contextily>=1.0.0->geoplot) (1.2.1)
# Requirement already satisfied: joblib in /home/julian/anaconda3/lib/python3.9/site-packages (from contextily>=1.0.0->geoplot) (1.1.0)
# Requirement already satisfied: xyzservices in /home/julian/anaconda3/lib/python3.9/site-packages (from contextily>=1.0.0->geoplot) (2022.6.0)
# Requirement already satisfied: shapely<2,>=1.7 in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas>=0.9.0->geoplot) (1.8.2)
# Requirement already satisfied: fiona>=1.8 in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas>=0.9.0->geoplot) (1.8.21)
# Requirement already satisfied: packaging in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas>=0.9.0->geoplot) (21.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /home/julian/anaconda3/lib/python3.9/site-packages (from geopandas>=0.9.0->geoplot) (3.3.1)
# Requirement already satisfied: networkx in /home/julian/anaconda3/lib/python3.9/site-packages (from mapclassify>=2.1->geoplot) (2.7.1)
# Requirement already satisfied: numpy>=1.3 in /home/julian/anaconda3/lib/python3.9/site-packages (from mapclassify>=2.1->geoplot) (1.21.5)
# Requirement already satisfied: scikit-learn in /home/julian/anaconda3/lib/python3.9/site-packages (from mapclassify>=2.1->geoplot) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from mapclassify>=2.1->geoplot) (1.7.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.2->geoplot) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.2->geoplot) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.2->geoplot) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/julian/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.2->geoplot) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/julian/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1.2->geoplot) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from pandas->geoplot) (2021.3)
# Requirement already satisfied: pyshp>=2.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from cartopy->geoplot) (2.3.0)
# Requirement already satisfied: munch in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (2.5.0)
# Requirement already satisfied: setuptools in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (61.2.0)
# Requirement already satisfied: cligj>=0.5 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (0.7.2)
# Requirement already satisfied: certifi in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (2021.10.8)
# Requirement already satisfied: click-plugins>=1.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (1.1.1)
# Requirement already satisfied: click>=4.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (8.0.4)
# Requirement already satisfied: six>=1.7 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (1.16.0)
# Requirement already satisfied: attrs>=17 in /home/julian/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.9.0->geoplot) (21.4.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/julian/anaconda3/lib/python3.9/site-packages (from geopy->contextily>=1.0.0->geoplot) (1.52)
# Requirement already satisfied: affine in /home/julian/anaconda3/lib/python3.9/site-packages (from rasterio->contextily>=1.0.0->geoplot) (2.3.1)
# Requirement already satisfied: snuggs>=1.4.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from rasterio->contextily>=1.0.0->geoplot) (1.4.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from requests->contextily>=1.0.0->geoplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/julian/anaconda3/lib/python3.9/site-packages (from requests->contextily>=1.0.0->geoplot) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/julian/anaconda3/lib/python3.9/site-packages (from requests->contextily>=1.0.0->geoplot) (1.26.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/julian/anaconda3/lib/python3.9/site-packages (from scikit-learn->mapclassify>=2.1->geoplot) (2.2.0)

# %%
import requests
import re
import random
import numpy as np
from pymongo import MongoClient
from pyspark import SparkContext
from bs4 import BeautifulSoup
import pandas as pd
from pyspark.sql import SparkSession
from pyspark import SparkConf
from pyspark.sql.functions import *
from pyspark.sql.types import *
import matplotlib.pyplot as plt
from json import dumps
import meteostat as ms
import datetime as dt
from dateutil import parser
import geopandas as gpd
import geoplot
import seaborn as sn

# %% [markdown]
# ### Gathering, Storing and Cleaning our Data
# The data will be collected and processed via Kafka, analyzed with Spark and all the relevant data will be stored on our MongoDB instance after an ETL-style pipeline.

# %% [markdown]
# ##### Setting up DB connection
# We're connecting to our local MongoDB instance, this is to pipe our extracted and transformed data into the DB later.

# %%
# Provide the mongodb connection string
# For non-Julian Laptops CONNECTION_STRING = 'mongodb://localhost:27017'
CONNECTION_STRING = 'mongodb://Mongo:mongo@192.168.50.25:27017'

# Create a connection using MongoClient
myclient = MongoClient(CONNECTION_STRING)

# Check DB collections
for db in myclient.list_databases():
    print(db)
# Out:
# {'name': 'Project', 'sizeOnDisk': 151552, 'empty': False}
# {'name': 'Sleepstudy', 'sizeOnDisk': 159744, 'empty': False}
# {'name': 'admin', 'sizeOnDisk': 102400, 'empty': False}
# {'name': 'config', 'sizeOnDisk': 110592, 'empty': False}
# {'name': 'local', 'sizeOnDisk': 73728, 'empty': False}
# {'name': 'wienerLinien', 'sizeOnDisk': 6488064, 'empty': False}

# %% [markdown]
# ##### Scraping together historical Wiener Linien Data
# For this step, we're using the Öffi.at website by Klaus Kirnbauer who has aggregated all historical Wiener Linien public transport incidents in an easily queriable fashion.
#
# Since Öffi.at uses conveniently utilizes server-side rendering, we can use BeautifulSoup for our data transformation.

# %% [markdown]
# Now first, we need to model a framework of parsing the relevant data from the 1520 available historical sites;\
# Since the data is variable in some cases we have decided on the following format:
#
# | [Affected Lines] | [Affected Stations] | Start Time | End Time | Time Problem Fixed | Title |
# |------------------|---------------------|------------|----------|--------------------|-------|

# %%
# Format
# ([Affected Lines], [Affected Stations], Start Time, End Time, Time Problem Fixed, Title)
def parse_oeffi_soup(soup):
    data = list(map(lambda li: (list(map(lambda trafficline: trafficline.getText(), li.select('.trafficline'))), 
                                 list(map(lambda liSub: liSub.split('<li>')[1],
                                     list(filter(re.compile('[^+]*\n<b>Von</b>:.').match, str(li).split('<br/>')))[0].split('</li>')[0:-1])),
                                 list(filter(re.compile('[^+]*\n<b>Von</b>:.').match, str(li).split('<br/>')))[0].split('<b>Von</b>: ')[1],
                                 list(filter(re.compile('\n<b>Bis</b>:').match, str(li).split('<br/>'))),
                                 list(filter(re.compile('\n<b>Verkehrsaufnahme</b>:').match, str(li).split('<br/>'))),
                                 li.select('.disruption-title')[0].getText()),
                     soup.select('li.disruption')))

    return list(map(lambda x: (x[0], x[1], x[2], x[3][0].split('</b>: ')[1] if len(x[3]) > 0 else None, x[4][0].split('</b>: ')[1] if len(x[4]) > 0 else None, x[5]), data))

# %% [markdown]
# And now we can run this model on all the available sites and aggregate this data! \
# For estimation, this takes around 15-20 minutes to run to completion with all 1520 requests.

# %%
data = []

for i in range(1, 1520):
    URL = 'https://xn--ffi-rna.at/?archive=1&page=' + str(i)
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')
    data.extend(parse_oeffi_soup(soup))
    
display(data)

# %% [markdown]
# Now we shall create a database for inserting our scraped data:

# %%
# Create Database
db = myclient['wienerLinien']

# %% [markdown]
# After arduously gathering and cleaning our data, we'll now convert it to a Dataframe and insert it into our Mongo DB instance:

# %%
# Transform into Pandas DF
df = pd.DataFrame(data, columns=['Affected Lines', 'Affected Stations', 'Start Time', 'End Time', 'Fixed Time', 'Title'])

# Insert
db.stoerungen.drop()
db.stoerungen.insert_many(df.to_dict('records'))

# %% [markdown]
# Now we can also check if we have inserted our data correctly:

# %%
stoerungen_col = db['stoerungen']
print('Stoerungen: ', len(list(stoerungen_col.find())))
# Out:
# Stoerungen:  27090

# %% [markdown]
# ##### Gathering Geodata about Stations
# For this step we read in a data.gv.at flat file for further usage in visualizing and interpreting the data:

# %%
import geopandas as gpd
#parse flatfile to pandas dataframe
haltestellen = pd.read_csv('wienerlinien-ogd-haltestellen.csv', sep=';')
print(haltestellen.head())

#insert df into mongoDB
db.haltestellen.drop()
db.haltestellen.insert_many(haltestellen.to_dict('records'))
# Out:
#        DIVA        PlatformText Municipality  MunicipalityID  Longitude  \
# 0  60200001  Schrankenberggasse         Wien           90001  16.389807
# 1  60200002          Achengasse         Wien           90001  16.448898
# 2  60200003  Ada-Christen-Gasse         Wien           90001  16.385953
# 3  60200004     Adam-Betz-Gasse         Wien           90001  16.535191
# 4  60200005      Adamovichgasse         Wien           90001  16.337840
#
#     Latitude
# 0  48.173801
# 1  48.284526
# 2  48.152866
# 3  48.215611
# 4  48.142167

# %%
haltestellen_col = db['haltestellen']
print('Haltestellen: ', len(list(haltestellen_col.find())))
# Out:
# Haltestellen:  10860

# %% [markdown]
# ##### Gathering Twitter data

# %% [markdown]
# For XYZ reasons we're using the Twitter API to gather XYZ as follows:
#
# // TODO: Write Twitter API code

# %% [markdown]
# ##### Setting up Spark via SparkContext for MongoDB

# %%
spark = SparkSession \
    .builder \
    .appName("WienerLinienAnalyse") \
    .getOrCreate()
# Out:
# 22/06/27 22:01:15 WARN Utils: Your hostname, Phoenix resolves to a loopback address: 127.0.1.1; using 192.168.0.131 instead (on interface enp38s0)
# 22/06/27 22:01:15 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/julian/anaconda3/lib/python3.9/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/06/27 22:01:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ### Analysis
#
# Graphs, maps and heatmaps showing / highlighting patterns and outages of the Viennese public transport system.
#
# #### Line Outage Analysis
# Firstly, we shall investigate which lines have been most affected by outages since June 2020.
#
# For this, we will read in our data from the DB into a Spark Dataframe:

# %%
dfStoerung = pd.DataFrame(list(db['stoerungen'].find()), columns = ['Affected Lines','Affected Stations','Start Time','End Time','Time Problem Fixed','Title'])
sparkDf = spark.createDataFrame(dfStoerung) 
sparkDf.printSchema()
sparkDf.show()
# Out:
# root
#  |-- Affected Lines: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- Affected Stations: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- Start Time: string (nullable = true)
#  |-- End Time: string (nullable = true)
#  |-- Time Problem Fixed: double (nullable = true)
#  |-- Title: string (nullable = true)
#
# +--------------+--------------------+----------------+----------------+------------------+--------------------+
# |Affected Lines|   Affected Stations|      Start Time|        End Time|Time Problem Fixed|               Title|
# +--------------+--------------------+----------------+----------------+------------------+--------------------+
# |          [60]|[ Hermesstraße, A...|26.06.2022 07:34|26.06.2022 16:53|               NaN|        Verspätungen|
# |          [33]|[Althanstraße, Au...|26.06.2022 07:43|26.06.2022 15:06|               NaN|        Verspätungen|
# |          [52]|[Ameisgasse, Ansc...|26.06.2022 07:57|26.06.2022 23:59|               NaN|        Verspätungen|
# |         [48A]|[Baumgartner Höhe...|26.06.2022 08:44|26.06.2022 23:59|               NaN|    : Verkehrsunfall|
# |          [10]|[ Hummelgasse, Do...|26.06.2022 09:06|26.06.2022 17:11|               NaN|        Verspätungen|
# |          [31]|[Anton-Schall-Gas...|26.06.2022 09:17|26.06.2022 13:27|               NaN|        Verspätungen|
# |          [25]|[ Oberdorfstraße,...|26.06.2022 09:30|26.06.2022 11:30|               NaN|        Verspätungen|
# |          [42]|[Antonigasse, Edu...|26.06.2022 09:53|26.06.2022 23:59|               NaN|        Verspätungen|
# |          [46]|[Auerspergstraße,...|26.06.2022 10:30|26.06.2022 23:59|               NaN|        Verspätungen|
# |          [30]|[Anton-Schall-Gas...|26.06.2022 10:50|26.06.2022 23:59|               NaN|        Verspätungen|
# |   [6, 18, 62]|         [6, 18, 62]|15.07.2022 01:15|15.07.2022 05:15|               NaN|Matzleinsdorfer P...|
# |          [U1]|  [Kaisermühlen-VIC]|26.07.2022 20:45|27.07.2022 00:45|               NaN|        Kaisermühlen|
# |          [U6]|          [Alterlaa]|24.07.2022 20:45|25.07.2022 00:45|               NaN|            Alterlaa|
# |   [1, 18, 62]|         [1, 18, 62]|28.07.2022 00:50|28.07.2022 04:45|               NaN|        Kliebergasse|
# |          [U6]|          [Alterlaa]|25.07.2022 01:15|25.07.2022 05:15|               NaN|            Alterlaa|
# |          [U6]|        [Neue Donau]|26.06.2022 07:44|            null|               NaN|          Neue Donau|
# |           [1]|[ Hauptallee, Bur...|25.06.2022 15:24|25.06.2022 23:59|               NaN|Schadhaftes Fahrzeug|
# |          [U1]|[Aderklaaer Straß...|25.06.2022 15:56|25.06.2022 23:59|               NaN|        Verspätungen|
# |          [10]|[ Hummelgasse, Do...|25.06.2022 16:51|26.06.2022 00:20|               NaN|        Verspätungen|
# |          [U4]|[Braunschweiggass...|25.06.2022 16:51|25.06.2022 23:59|               NaN|     Betriebsstörung|
# +--------------+--------------------+----------------+----------------+------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# For all the further steps of analysis, we will need to define a temporary view which represents our MongoDB table:

# %%
sparkDf.createTempView('stoerungen')

# %% [markdown]
# Next, we will analyze our data based on the Affected Lines:

# %%
affectedDf = spark.sql("select `Affected Lines` from stoerungen")
affectedDf.show()
# Out:
# +--------------+
# |Affected Lines|
# +--------------+
# |          [60]|
# |          [33]|
# |          [52]|
# |         [48A]|
# |          [10]|
# |          [31]|
# |          [25]|
# |          [42]|
# |          [46]|
# |          [30]|
# |   [6, 18, 62]|
# |          [U1]|
# |          [U6]|
# |   [1, 18, 62]|
# |          [U6]|
# |          [U6]|
# |           [1]|
# |          [U1]|
# |          [10]|
# |          [U4]|
# +--------------+
# only showing top 20 rows

# %% [markdown]
# Now we will use the power of Spark to count all occurences of outages for all lines:

# %%
# Convert to List and flatMap, for count
affected = affectedDf.rdd \
                     .flatMap(lambda x: x) \
                     .flatMap(lambda x: x) \
                     .map(lambda w: (w,1)) \
                     .reduceByKey(lambda a, b: a+b) 

affected.collect() # Output
# Out:
# 22/06/27 22:01:24 WARN TaskSetManager: Stage 2 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# [('48A', 221),
#  ('U1', 1783),
#  ('U4', 1684),
#  ('40', 303),
#  ('44', 412),
#  ('38A', 86),
#  ('63A', 223),
#  ('11A', 141),
#  ('14A', 229),
#  ('71A', 10),
#  ('49A', 10),
#  ('64A', 37),
#  ('94A', 8),
#  ('73A', 6),
#  ('N46', 19),
#  ('92A', 15),
#  ('92B', 5),
#  ('19A', 3),
#  ('99B', 2),
#  ('42', 439),
#  ('18', 737),
#  ('62', 933),
#  ('49', 650),
#  ('66A', 149),
#  ('28A', 31),
#  ('59A', 147),
#  ('76B', 7),
#  ('37A', 24),
#  ('13A', 403),
#  ('U3', 2084),
#  ('65A', 53),
#  ('56A', 10),
#  ('1A', 105),
#  ('N62', 10),
#  ('60A', 37),
#  ('79A', 4),
#  ('17A', 8),
#  ('54B', 4),
#  ('N68', 1),
#  ('7B', 2),
#  ('N65', 5),
#  ('8A', 4),
#  ('7A', 242),
#  ('D', 823),
#  ('2', 1153),
#  ('77A', 42),
#  ('N66', 23),
#  ('40A', 128),
#  ('47A', 11),
#  ('85A', 5),
#  ('20A', 5),
#  ('95B', 2),
#  ('N17', 1),
#  ('N35', 6),
#  ('60', 663),
#  ('10', 477),
#  ('29A', 63),
#  ('WLB', 92),
#  ('56B', 5),
#  ('69A', 84),
#  ('93A', 12),
#  ('51A', 9),
#  ('79B', 2),
#  ('50A', 15),
#  ('N29', 29),
#  ('54A', 7),
#  ('58A', 3),
#  ('25', 437),
#  ('6', 653),
#  ('10A', 253),
#  ('24A', 43),
#  ('30A', 40),
#  ('42A', 5),
#  ('67B', 19),
#  ('N71', 21),
#  ('N60', 69),
#  ('98A', 6),
#  ('N38', 11),
#  ('82A', 14),
#  ('97A', 6),
#  ('44A', 10),
#  ('N23', 4),
#  ('50B', 6),
#  ('99A', 1),
#  ('33', 296),
#  ('U2', 1281),
#  ('32A', 53),
#  ('U2Z', 139),
#  ('5A', 110),
#  ('84A', 18),
#  ('67A', 19),
#  ('49B', 1),
#  ('89A', 1),
#  ('39A', 89),
#  ('9A', 92),
#  ('87A', 31),
#  ('86A', 24),
#  ('53A', 1),
#  ('26', 514),
#  ('62A', 58),
#  ('26A', 95),
#  ('4A', 113),
#  ('O', 611),
#  ('N43', 190),
#  ('N41', 10),
#  ('N75', 3),
#  ('88B', 5),
#  ('46B', 2),
#  ('31', 582),
#  ('30', 192),
#  ('12A', 247),
#  ('2A', 126),
#  ('71', 761),
#  ('43', 575),
#  ('22A', 23),
#  ('68B', 29),
#  ('N8', 23),
#  ('34A', 7),
#  ('96A', 1),
#  ('36A', 20),
#  ('72A', 2),
#  ('58B', 7),
#  ('88A', 3),
#  ('N67', 2),
#  ('U6', 1709),
#  ('1', 1204),
#  ('57A', 188),
#  ('9', 711),
#  ('80A', 56),
#  ('5B', 90),
#  ('16A', 59),
#  ('15A', 106),
#  ('71B', 4),
#  ('25A', 12),
#  ('95A', 20),
#  ('N20', 7),
#  ('N49', 125),
#  ('61A', 28),
#  ('N26', 8),
#  ('47B', 5),
#  ('N31', 11),
#  ('52E', 1),
#  ('N24', 2),
#  ('52', 405),
#  ('46', 486),
#  ('41', 344),
#  ('11', 582),
#  ('5', 721),
#  ('38', 312),
#  ('37', 315),
#  ('35A', 91),
#  ('N6', 37),
#  ('3A', 128),
#  ('27A', 55),
#  ('36B', 38),
#  ('43B', 5),
#  ('52A', 7),
#  ('31A', 49),
#  ('76A', 7),
#  ('68A', 26),
#  ('N25', 24),
#  ('11B', 25),
#  ('74A', 105),
#  ('43A', 6),
#  ('33A', 7),
#  ('52B', 5),
#  ('VRT', 10),
#  ('46A', 3)]

# %% [markdown]
# And now we would like to query this information for the top 20 least and top 20 most affected lines:

# %%
# Get top 20 most affected lines
top20 = affected.sortBy(lambda x: x[1], False) \
                .take(20)
top20
# Out:
# [('U3', 2084),
#  ('U1', 1783),
#  ('U6', 1709),
#  ('U4', 1684),
#  ('U2', 1281),
#  ('1', 1204),
#  ('2', 1153),
#  ('62', 933),
#  ('D', 823),
#  ('71', 761),
#  ('18', 737),
#  ('5', 721),
#  ('9', 711),
#  ('60', 663),
#  ('6', 653),
#  ('49', 650),
#  ('O', 611),
#  ('31', 582),
#  ('11', 582),
#  ('43', 575)]

# %%
# Get top 20 least affected lines
low20 = affected.sortBy(lambda x: x[1]) \
                .take(20)
low20
# Out:
# [('N68', 1),
#  ('N17', 1),
#  ('99A', 1),
#  ('49B', 1),
#  ('89A', 1),
#  ('53A', 1),
#  ('96A', 1),
#  ('52E', 1),
#  ('99B', 2),
#  ('7B', 2),
#  ('95B', 2),
#  ('79B', 2),
#  ('46B', 2),
#  ('72A', 2),
#  ('N67', 2),
#  ('N24', 2),
#  ('19A', 3),
#  ('58A', 3),
#  ('N75', 3),
#  ('88A', 3)]

# %%
# Top 20 
plt.bar(range(len(top20)), [val[1] for val in top20], align='center', color=['red'])
plt.xticks(range(len(top20)), [val[0] for val in top20])
plt.xticks(rotation=70)
plt.show()

# %%
# Lowest 20 
plt.bar(range(len(low20)), [val[1] for val in low20], align='center', color=['green'])
plt.yticks([0,1,2,3])
plt.xticks(range(len(low20)), [val[0] for val in low20])
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# From this we can immediately see that lines which are heavily utilized such as the U3 and U1 which service the city center tend to have much more outages reported!
#
# From the lowest 10, a few are Nightlines which don't need to deal with a lot of traffic anyways and in general just lesser known lines, mostly servicing the car friendly areas such as the 22nd district (99A, 96A, 89A, 99B, etc.)

# %% [markdown]
# sn.heatmap(corrMatrix, annot=True)
# plt.show()##### Common Outage Causes
#
# For this we will attempt to analyze more common causes for outages, such as false parking, damaged rails or the recent pride parade. 🏳️‍🌈

# %%
demonstrationCount = spark.sql("""select (select count(title) from stoerungen where title like '%Rettungseinsatz%') as Rettungseinsatz,
                                         (select count(title) from stoerungen where title like '%Falschparker%') as Falschparker,
                                         (select count(title) from stoerungen where title like '%Feuerwehr%') as Feuerwehr,
                                         (select count(title) from stoerungen where title like '%Polizei%') as Polizeieinsatz,
                                         (select count(title) from stoerungen where title like '%Demonstration%') as Demo,
                                         (select count(title) from stoerungen where title like '%Verkehrsbedingt%') as Stau,
                                         (select count(title) from stoerungen where title like '%Verkehrsunfall%') as Verkehrsunfall,
                                         (select count(title) from stoerungen where title like '%Schadhaft%') as FahrzeugSchaden,
                                         (select count(title) from stoerungen where title like '%Gleisschaden%') as Gleisschaden,
                                         (select count(title) from stoerungen where title like '%Regenbogenparade%') as Regenbogen""")
demonstrationCount.show()
# Out:
# 22/06/27 22:01:40 WARN TaskSetManager: Stage 24 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:40 WARN TaskSetManager: Stage 32 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:40 WARN TaskSetManager: Stage 25 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:40 WARN TaskSetManager: Stage 26 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:40 WARN TaskSetManager: Stage 30 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:40 WARN TaskSetManager: Stage 29 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:40 WARN TaskSetManager: Stage 28 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:41 WARN TaskSetManager: Stage 27 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:41 WARN TaskSetManager: Stage 31 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:41 WARN TaskSetManager: Stage 33 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# +---------------+------------+---------+--------------+----+----+--------------+---------------+------------+----------+
# |Rettungseinsatz|Falschparker|Feuerwehr|Polizeieinsatz|Demo|Stau|Verkehrsunfall|FahrzeugSchaden|Gleisschaden|Regenbogen|
# +---------------+------------+---------+--------------+----+----+--------------+---------------+------------+----------+
# |           2547|        2010|      668|          1548|1408| 982|          3012|           1983|         166|        45|
# +---------------+------------+---------+--------------+----+----+--------------+---------------+------------+----------+

# %%
demonstrationCountPandas = demonstrationCount.toPandas() 
colnames = list(demonstrationCountPandas)
values = demonstrationCountPandas.to_numpy().tolist()[0]

data = list(zip(colnames, values))
data.sort(key=lambda x: x[1], reverse=True)
data
# Out:
# 22/06/27 22:01:45 WARN TaskSetManager: Stage 55 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:45 WARN TaskSetManager: Stage 56 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:45 WARN TaskSetManager: Stage 57 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:45 WARN TaskSetManager: Stage 58 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:45 WARN TaskSetManager: Stage 59 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:45 WARN TaskSetManager: Stage 61 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:46 WARN TaskSetManager: Stage 60 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:46 WARN TaskSetManager: Stage 62 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:46 WARN TaskSetManager: Stage 63 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# 22/06/27 22:01:46 WARN TaskSetManager: Stage 64 contains a task of very large size (1052 KiB). The maximum recommended task size is 1000 KiB.
# [('Verkehrsunfall', 3012),
#  ('Rettungseinsatz', 2547),
#  ('Falschparker', 2010),
#  ('FahrzeugSchaden', 1983),
#  ('Polizeieinsatz', 1548),
#  ('Demo', 1408),
#  ('Stau', 982),
#  ('Feuerwehr', 668),
#  ('Gleisschaden', 166),
#  ('Regenbogen', 45)]

# %%
plt.bar(range(len(data)), [val[1] for val in data], align='center')
plt.xticks(range(len(data)), [val[0] for val in data])
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# Here we can obviously see that there have been some common issues in the last few years.
# For example, road accidents is the most cited reason for outages we've inspected, followed by ambulance services and wrong parkers!
#
# Demonstrations, police activity and damaged wagons also account for many reported reasons while we can also observe a small number attributed to railway issues and even 14 outages directly related to the Rainbow Parade. :-)

# %% [markdown]
# dd03ae42c25e
# #### Generating a Heat Map of most affected stations
# First we need to create a geodataframe. It is similar to a regular pandas dataframe but the longtitude and latitude are transformed to a point.

# %%
tb_gdf = gpd.GeoDataFrame(haltestellen,
                          geometry=gpd.points_from_xy(haltestellen.Longitude, haltestellen.Latitude))

tb_gdf.head()
# Out:
#        DIVA        PlatformText Municipality  MunicipalityID  Longitude  \
# 0  60200001  Schrankenberggasse         Wien           90001  16.389807
# 1  60200002          Achengasse         Wien           90001  16.448898
# 2  60200003  Ada-Christen-Gasse         Wien           90001  16.385953
# 3  60200004     Adam-Betz-Gasse         Wien           90001  16.535191
# 4  60200005      Adamovichgasse         Wien           90001  16.337840
#
#     Latitude                   geometry
# 0  48.173801  POINT (16.38981 48.17380)
# 1  48.284526  POINT (16.44890 48.28453)
# 2  48.152866  POINT (16.38595 48.15287)
# 3  48.215611  POINT (16.53519 48.21561)
# 4  48.142167  POINT (16.33784 48.14217)

# %% [markdown]
# ##### Generating map of Vienna
# Now we will use the shapefile (.shp) provided by the austrian goverment, to generate a plot of vienna.

# %%
viennaBez = gpd.read_file('./BEZIRKSGRENZEOGDPolygon.shp');
viennaBezPlot = viennaBez.plot(color='white', edgecolor='black');
viennaBezPlot.plot();

# %%
viennaBez = gpd.read_file('./BEZIRKSGRENZEOGDPolygon.shp');
viennaBezPlot = viennaBez.plot(color='white', edgecolor='black');
haltestellen=haltestellen[(haltestellen.Longitude > 16.2) & (haltestellen.Longitude < 16.55) & (haltestellen.Latitude<48.3) & (haltestellen.Latitude >48.15)]
tb_gdf = gpd.GeoDataFrame(haltestellen,
                          geometry=gpd.points_from_xy(haltestellen.Longitude, haltestellen.Latitude))

tb_gdf.head()
tb_gdf.plot( ax=viennaBezPlot,markersize=2);

# %%
import geoplot
ax = geoplot.polyplot(viennaBez, projection=geoplot.crs.AlbersEqualArea(),zorder=1)
geoplot.kdeplot(tb_gdf, ax=ax,cmap='Reds', shade=True)

# %% [markdown]
# ## What influence does the weather have?

# %% [markdown]
# To find out, we look at the weather metrics whenever there is a disruption and compare them to data from an equal amount of random days from the past 2 years.

# %%
colweather=db["Weather"]
myfilter={"time":1,"coco":1,"dwpt":1,"prcp":1,"pres":1,"rhum":1,"temp":1,"tsun":1,"wdir":1,"wpgt":1,"wspd":1}
mydoc=colweather.find({},myfilter)
delayweather=[]
l=0
for x in mydoc:
    l=l+1
    x["delay"]=1
    x["time"]=x["time"]-dt.timedelta(hours=2)
    x.pop("_id",None)
    delayweather.append(x)

# %%
delayweather=pd.DataFrame(delayweather)#,columns=["time","coco","dwpt","prcp","pres","rhum","temp","tsun","wdir","wpgt","wspd"])
#delayweather=delayweather.reindex(columns=["time","tavg","tmin","tmax","prcp","snow","wdir","wspd","wpgt","pres","datatype"])
delayweather=spark.createDataFrame(delayweather)
delayweather=delayweather.na.fill(0,["coco","dwpt","prcp","pres","rhum","temp","tsun","wdir","wpgt","wspd"])
delayweather.show()
# Out:
# +----+----+----+----+-----+----+----+------+----+----+-------------------+-----+
# |temp|dwpt|rhum|prcp| wdir|wspd|wpgt|  pres|tsun|coco|               time|delay|
# +----+----+----+----+-----+----+----+------+----+----+-------------------+-----+
# |28.5|14.0|41.0| 0.0| 66.0| 7.4|13.0|1014.8|60.0| 2.0|2022-06-26 12:00:00|    1|
# |21.9|13.8|60.0| 0.0|273.0|18.5|33.3|1014.3|24.0| 3.0|2022-06-25 12:00:00|    1|
# |28.5|15.1|44.0| 0.0|140.0|22.2|38.9|1010.7|53.0| 2.0|2022-06-24 12:00:00|    1|
# |27.4|12.6|40.0| 0.0|354.0| 7.4|14.8|1014.1|56.0| 2.0|2022-06-23 12:00:00|    1|
# |26.4| 9.7|35.0| 0.0|125.0|11.1|20.4|1011.8|60.0| 2.0|2022-06-22 12:00:00|    1|
# |22.6| 6.4|35.0| 0.0|316.0|13.0|22.2|1013.8|60.0| 2.0|2022-06-21 12:00:00|    1|
# |30.0|16.1|43.0| 0.0|274.0| 9.3|18.5|1007.6|28.0| 2.0|2022-06-20 12:00:00|    1|
# |31.3|11.1|29.0| 0.0|152.0|27.8|48.2|1012.0|60.0| 1.0|2022-06-19 12:00:00|    1|
# |28.3|10.5|33.0| 0.0|172.0| 9.3|20.4|1020.0|60.0| 2.0|2022-06-18 12:00:00|    1|
# |23.9|10.6|43.0| 0.0|318.0|16.7|31.5|1022.1|43.0| 2.0|2022-06-17 12:00:00|    1|
# |28.0|13.9|42.0| 0.0|159.0|11.1|22.2|1015.3|59.0| 2.0|2022-06-16 12:00:00|    1|
# |25.8|10.0|37.0| 0.0|125.0|13.0|22.2|1018.7|58.0| 2.0|2022-06-15 12:00:00|    1|
# |21.7| 6.8|38.0| 0.0|311.0| 9.3|20.4|1021.2|41.0| 2.0|2022-06-14 12:00:00|    1|
# |26.1|14.9|50.0| 0.0|280.0|18.0|44.3|1014.1|56.0|18.0|2022-06-13 12:00:00|    1|
# |25.3|15.3|54.0| 0.0|310.0| 7.0|27.4|1016.6|50.0| 0.0|2022-06-06 12:00:00|    1|
# |19.3|10.0|55.0| 0.0| 17.0| 7.4|14.8|1020.9| 0.0| 3.0|2022-05-06 12:00:00|    1|
# |18.0| 5.6|44.0| 0.0|179.0|11.1|22.2|1007.0|13.0| 3.0|2022-04-06 12:00:00|    1|
# | 3.0|-6.7|49.0| 0.0|332.0|11.1|18.5|1022.3| 6.0| 3.0|2022-03-06 11:00:00|    1|
# | 9.1|-3.5|41.0| 0.0|233.0|16.7|35.2|1015.4|46.0| 3.0|2022-02-06 11:00:00|    1|
# | 5.2|-2.4|58.0| 0.0|288.0|22.2|46.3|1014.9|26.0| 3.0|2022-01-06 11:00:00|    1|
# +----+----+----+----+-----+----+----+------+----+----+-------------------+-----+
# only showing top 20 rows

# %%
daylist=random.sample(range(0,730),l)
Vienna = ms.Point(48.210, 16.363)
today=dt.datetime.today().replace(hour=12,minute=0, second=0, microsecond=0)

# %%
randomweather=[]
for x in daylist:
    day=today-dt.timedelta(days=x)
    res = ms.Hourly(Vienna,day,day)
    df=res.fetch()
    mydict=df.to_dict()
    ts=list(mydict[list(mydict)[0]])[0]
    ts=ts.to_pydatetime()
    for key in mydict:
        mydict[key]=mydict[key][list(mydict[key])[0]]
    mydict["time"]=ts
    mydict["delay"]=0
    randomweather.append(mydict)

# %%
randomweather=pd.DataFrame(randomweather)
randomweather=spark.createDataFrame(randomweather)
randomweather=randomweather.drop("snow")
randomweather=randomweather.na.fill(0,["coco","dwpt","prcp","pres","rhum","temp","tsun","wdir","wpgt","wspd"])
randomweather.show()
# Out:
# +----+----+----+----+-----+----+----+------+----+----+-------------------+-----+
# |temp|dwpt|rhum|prcp| wdir|wspd|wpgt|  pres|tsun|coco|               time|delay|
# +----+----+----+----+-----+----+----+------+----+----+-------------------+-----+
# |14.6| 9.2|70.0| 0.0|285.0|16.7|31.5|1023.7| 0.0| 4.0|2020-10-31 12:00:00|    0|
# |17.9|12.8|72.0| 0.0|276.0|24.1|42.6|1016.2| 0.0| 7.0|2021-08-31 12:00:00|    0|
# |23.7|11.7|47.0| 0.0| 52.0| 7.4|13.0|1019.9|60.0| 2.0|2021-08-09 12:00:00|    0|
# | 4.3|-2.3|62.0| 0.0|294.0|22.2|42.6|1015.8|41.0| 3.0|2022-02-01 12:00:00|    0|
# |11.7|-0.5|43.0| 0.0|263.0|22.2|51.8|1003.3| 6.0| 3.0|2022-02-21 12:00:00|    0|
# |18.0| 4.9|42.0| 0.0|276.0|20.4|38.9|1007.8|47.0| 3.0|2021-05-16 12:00:00|    0|
# |17.9| 4.1|40.0| 0.0|299.0|14.8|25.9|1012.9| 0.0| 3.0|2022-05-29 12:00:00|    0|
# |14.1| 2.0|44.0| 0.0|  4.0| 7.4|14.8|1030.7|60.0| 2.0|2022-03-27 12:00:00|    0|
# |14.5| 6.8|60.0| 0.0|290.0|16.7|29.6|1013.2| 0.0| 4.0|2021-05-19 12:00:00|    0|
# |14.3|-5.5|25.0| 0.0|153.0|14.8|25.9|1020.2| 0.0| 2.0|2021-04-09 12:00:00|    0|
# |20.5|10.9|54.0| 0.0|143.0|20.4|35.2|1012.5|60.0| 2.0|2021-10-03 12:00:00|    0|
# | 8.0| 5.5|84.0| 0.1|311.0|14.8|27.8|1013.9| 0.0| 7.0|2020-10-16 12:00:00|    0|
# | 2.9|-2.4|68.0| 0.0|318.0|11.1|20.4|1013.8| 6.0| 3.0|2021-12-07 12:00:00|    0|
# | 1.5|-0.9|84.0| 0.0|349.0| 7.4|14.8|1014.3| 0.0| 4.0|2021-12-11 12:00:00|    0|
# | 6.2|-2.4|54.0| 0.0|277.0|24.1|53.7|1028.3| 0.0| 3.0|2022-02-08 12:00:00|    0|
# |13.2| 1.2|44.0| 0.0|292.0| 5.5|13.0|1020.8|60.0| 2.0|2021-03-25 12:00:00|    0|
# |24.0|14.7|56.0| 0.0|316.0|13.0|22.2|1019.7|53.0| 3.0|2020-08-06 12:00:00|    0|
# |13.5| 1.5|44.0| 0.0|243.0|14.8|27.8|1012.3|12.0| 3.0|2022-02-18 12:00:00|    0|
# | 3.7|-3.8|58.0| 0.0|276.0|16.7|33.3|1038.1|30.0| 3.0|2022-01-13 12:00:00|    0|
# | 5.4| 3.2|86.0| 0.0|164.0| 5.5|13.0|1019.2| 0.0| 4.0|2021-11-13 12:00:00|    0|
# +----+----+----+----+-----+----+----+------+----+----+-------------------+-----+
# only showing top 20 rows

# %%
cols = [f"any({col} is null) as {col}_contains_null" 
        for col in randomweather.columns]

cols = [f"any({col} is null) as {col}_contains_null" 
        for col in delayweather.columns]

print("randomweather:")
randomweather.selectExpr(cols).show()
print("delayweather:")
delayweather.selectExpr(cols).show()
# Out:
# randomweather:
# +------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+
# |temp_contains_null|dwpt_contains_null|rhum_contains_null|prcp_contains_null|wdir_contains_null|wspd_contains_null|wpgt_contains_null|pres_contains_null|tsun_contains_null|coco_contains_null|time_contains_null|delay_contains_null|
# +------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+
# |             false|             false|             false|             false|             false|             false|             false|             false|             false|             false|             false|              false|
# +------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+
#
# delayweather:
# +------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+
# |temp_contains_null|dwpt_contains_null|rhum_contains_null|prcp_contains_null|wdir_contains_null|wspd_contains_null|wpgt_contains_null|pres_contains_null|tsun_contains_null|coco_contains_null|time_contains_null|delay_contains_null|
# +------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+
# |             false|             false|             false|             false|             false|             false|             false|             false|             false|             false|             false|              false|
# +------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-------------------+

# %%
allweather=delayweather.union(randomweather)
print(allweather.count())
# Out:
# 542

# %%
pdallweather=allweather.toPandas()
display(pdallweather)
# Out:
#      temp  dwpt  rhum  prcp   wdir  wspd  wpgt    pres  tsun  coco  \
# 0    28.5  14.0  41.0   0.0   66.0   7.4  13.0  1014.8  60.0   2.0
# 1    21.9  13.8  60.0   0.0  273.0  18.5  33.3  1014.3  24.0   3.0
# 2    28.5  15.1  44.0   0.0  140.0  22.2  38.9  1010.7  53.0   2.0
# 3    27.4  12.6  40.0   0.0  354.0   7.4  14.8  1014.1  56.0   2.0
# 4    26.4   9.7  35.0   0.0  125.0  11.1  20.4  1011.8  60.0   2.0
# ..    ...   ...   ...   ...    ...   ...   ...     ...   ...   ...
# 537  12.9  -2.2  35.0   0.0  125.0  16.7  29.6  1026.8   0.0   2.0
# 538  19.3  10.8  58.0   0.0  319.0  14.8  27.8  1022.2  12.0   3.0
# 539  14.8   6.6  58.0   0.0  105.0   5.5  13.0  1027.7  59.0   2.0
# 540   8.0   5.1  82.0   0.0  140.0  14.8  29.6  1005.2   0.0   4.0
# 541   9.0  -8.6  28.0   0.0  132.0  20.4  38.9  1039.9  25.0   1.0
#
#                    time  delay
# 0   2022-06-26 12:00:00      1
# 1   2022-06-25 12:00:00      1
# 2   2022-06-24 12:00:00      1
# 3   2022-06-23 12:00:00      1
# 4   2022-06-22 12:00:00      1
# ..                  ...    ...
# 537 2022-03-15 12:00:00      0
# 538 2020-09-07 12:00:00      0
# 539 2021-10-27 12:00:00      0
# 540 2020-12-07 12:00:00      0
# 541 2022-03-20 12:00:00      0
#
# [542 rows x 12 columns]

# %%
temp=pdallweather["temp"].tolist()
wpgt=pdallweather["wpgt"].tolist()
delay=pdallweather["delay"].tolist()


print(len(prcp))
print(len(wspd))
print(len(delay))
# Out:
# 542
# 542
# 542

# %%
newtemp=[]
newwpgt=[]
colors=[]
for x in range(len(delay)):
    if temp[x] != 0.0 and wpgt[x]!=0.0 and not wpgt[x]>62.5:
        newtemp.append(temp[x])
        newwpgt.append(wpgt[x])
        if delay[x] == 1:
            colors.append("red")
        else:
            colors.append("#33ccff")
        
print(len(colors))
# Out:
# 534

# %%
z = np.polyfit(newtemp, newwpgt, 1)
p = np.poly1d(z)

fig = plt.figure(figsize = (18, 10))

plt.xlabel("Temperature", fontsize="x-large")
plt.ylabel("Wind Speed", fontsize="x-large")

plt.scatter(newtemp,newwpgt,marker=".",c=colors)
plt.plot(newtemp,p(newtemp),color="black",linestyle="--")
         
plt.show()

# %%
fig = plt.figure(figsize = (18, 10))
sn.heatmap(pdallweather.corr(), annot=True)
plt.show()

# %%
import tweepy

client=tweepy.Client("AAAAAAAAAAAAAAAAAAAAAHJMdgEAAAAAaazY9nw6SjvKprN4BDsBWVjfIZU%3DlzAqZ4fbC4UTH1caM2XLfZYlTjszcqASp43jAiDcBBO9Lsv08H")
public_tweets =client.search_recent_tweets('"@WienerLinien" (Ausfall OR Störung OR Verspätung)')

for tweet in public_tweets[0]:
    print(tweet.text)
# Out:
# @wienerlinien Was macht ihr wenn es mal 1 Störung gibt und die Menschen bei den Temperaturen in der Klimalosen U-Bahn fest sitzen? 🤔
